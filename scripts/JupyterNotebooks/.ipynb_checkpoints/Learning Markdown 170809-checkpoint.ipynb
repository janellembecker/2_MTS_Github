# %% [markdown]
# # Learning Markdown
#
# Here is a link for [Jupyter's markdown docs](http://jupyter-notebook.readthedocs.io/en/latest/examples/Notebook/Working%20With%20Markdown%20Cells.html#General-HTML).
# Here is the [link for markdown basics](https://daringfireball.net/projects/markdown/basics).
#
#
# # Header 1
# ## Header 2
# ### Header 3
# #### Header 4
# ###### Header 5
# ####### Header 6 - there are only 5 levels
# ######## Header 7 - yep, only 5 levels
#
# ```python
# # Comments are reddish, but the color scheme is different than code sections...
# print("Hello world!")
#
# #example ------------------------------------------------------------
# import pandas as pd #this isn't green like in the "code" section...
#         # Nope, after viewing the preview, this looks right!
# def janellefunction(animal, name):
#     blah blah
#
# for i in range(len(df)):
#     if df['super_function'][i] == df['function'][i]:
#         df['function'][i] = df['function'][i] + " Total"
#     else:
#         df['function'][i] = df['function'][i]
# ```
#
# # Getting rid of output cells
# At the top, Cell > Cell Toolbar > either current or all > clear
#
# # Lists
# **==> You have to space after the character for it to make a header, list, etc. <==**
#
# ## Unordered
# - Interchangeable Un-ordered list
#     - What does tab do?
#         - Nailed it
#             - How far does this go?
#                 - And it's color coded for each layer?
#                     - Cool!
# * Interchangeable Un-ordered list
# + Interchangeable Un-ordered list
#
# ## Ordered
# 1. Here is the first bullet
#     - And how about tab here? (used a - here)
# 2. Here is the second bullet
#     * Bullets! --> tab plus whatever character you want * Will make a sub bullet
#     1. numbers! --> numbers will make a sub bullet
#     - a. letters! --> letters will NOT make a sub bullet. i actually used - a.
# 4. What happens when I skip a bullet and put #4?
#     - it properly numbered it #3 in the list, whaaaaat!
#
#
# # Tables
# This is a table, but it put it in the center instead of left-aligned.
#
# ### Example Table
# | This | is   |
# |------|------|
# |   a  | table|
#
# ### Take 1 - Not quite right...
# | bolded | bolded || bolded | bolded |
# |------|------||------|------|
# |   a  | table||   a  | table|
# |------|------||------|------|
# |   a  | table||   a  | table|
# |------|------||------|------|
# |   a  | table||   a  | table|
# |------|------||------|------|
# |   a  | table||   a  | table|
#
# ### Take 2 - use divider only once from variable names to actual cells
# | This | is   |
# |------|------|
# |   a  | table|
# |   a  | table|
# |   a  | table|
# |   a  | table|
# |   a  | table|
# |   a  | table|
#
# ### Take 3 - i want a larger table.
# Spacing doesn't matter, ie pipes dont have to visually line up.
# You MUST have a new line between text and table, otherwise itallgetssquishedup.
#
# | Index | Var1| Var2|Var3| Var4 |Var5| Var6 | Var7   |
# |------|------|------|------|------|------|------|------|
# |   1  | this|   is | a|   larger  | table|   example  | i got to work|
# |   2  | table|   a  | table|   a  | table|   a  | table|
# |   3  | table|   a  | table|   a  | table|   a  | table|
# |   4  | table|   a  | table|   a  | table|   a  | table|
# |   5  | table|   a  | table|   a  | table|   a  | table|
# |   6  | table|   a  | table|   a  | table|   a  | table|
#
#
#
#
# # Refer to local files, e.g. images
# -----> Local files in your Notebook directory <-----
#
# *Still unclear: what is the working directory*
#
# Since after opening and closing, the formerly not working are now working, I'm confused what my notebook directory is. Both the images on the desktop and in the specific folder when i called my cwd popped up...
#
# ### Back slash - not working?
# <img src="C:\Users\583902\Desktop\BAH1\_Treasury_DATA_Act\_Object_Class\colors palettes\Hex ALL DATA Act Colors Palette.png"/>
#
# ### Foward slash - not working?
# <img src="C:/Users/583902/Desktop/BAH1/_Treasury_DATA_Act/_Object_Class/colors palettes/Hex ALL DATA Act Colors Palette.png"/>
#
# ### Trying for Daring Fireball
# ![Pic Text](C:/Users/583902/Desktop/BAH1/_Treasury_DATA_Act/_Object_Class/colors palettes/Hex ALL DATA Act Colors Palette.png "Title")
#
# ### Stackoverflow says prefix for directory not needed if image is in notebook dir
#
# <img src="files/Hex ALL DATA Act Colors Palette.png"/>
#
# <img src="Hex ALL DATA Act Colors Palette.png"/>
#
# ![Pic Text](Hex ALL DATA Act Colors Palette.png)
#
#
# ### Trying image on desktop, which I think is actually the notebook directory?
#
# #### Option 1 - wasn't working, but now is...?
# <img src="TableauTreeMapRunningAway.gif"/>
#
# #### Option 2 - wasn't working, but now is...?
# ![Pic Text](TableauTreeMapRunningAway.gif)

# %%
# What is my current working directory?

import os
print(os.getcwd())
# Out:
# C:\Users\583902\Desktop\BAH1\_Treasury_DATA_Act\MTS\scripts\JupyterNotebooks

# %% [markdown]
# # Displaying local file (image), Attempt #2
#
#
# #### foward slash
# <img src="C:/Users/583902/Desktop/BAH1/_Treasury_DATA_Act/MTS/scripts/JupyterNotebooks/TableauTreeMapRunningAway.gif"/>
#
# #### back slash
# <img src="C:\Users\583902\Desktop\BAH1\_Treasury_DATA_Act\MTS\scripts\JupyterNotebooks\TableauTreeMapRunningAway.gif"/>
#
# #### < files/filename> option
# <img src="files/TableauTreeMapRunningAway.gif"/>
#
# #### < img src > without "files/" option
# <img src="TableauTreeMapRunningAway.gif"/>
#
# #### cleanest, simplest, i thikn native option? the ![text]( filename "title" option
# ![Pic Text](TableauTreeMapRunningAway.gif "This is a Title")
#
# #### png on the desktop, NOT in the MTS folder
# ![Does this dalek show up?](dalek.jpg "This is a Title")
# Answer: Yes
#
# #### png in the MTS folder, deleted from desktop
# ![Does this dalek show up?](dalek.jpg "This is a Title")
# Answer: Yes

# %% [markdown]
# # How to [center] align?
#
# you can't. use html.
#
# <h3><center>CENTERED TEXT I STOLE FROM ONLINE!</center></h3>

# %% [markdown]
# # How to delete cells from notebook?
#
# Edit > Delete cells
#
# ## Is there a shortcut/hotkey for this?
